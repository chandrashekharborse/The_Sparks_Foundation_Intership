# %% [markdown]
# #### TASK 3 - EDA For RETAIL STORE-GRIP CHANDRASHEKHAR BORSE

# %%
# For manipulation 
import numpy as np
import pandas as pd 

# for data visualization
import matplotlib.pyplot as plt
import seaborn as sns 

# for interactivity
from ipywidgets import interact

# %% [markdown]
# #### LOADING THE FILE AND CONVERTING INTO DATAFRAME

# %%
# Lets read dataset
data = pd.read_csv("SampleSuperstore.csv")
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# ##### PULLING OUT THE COLUMNS FOR ANALYSIS

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# ##### Lets check the shape of the dataset

# %%
print("shape of the dataset : ",data.shape)
# Out:
# shape of the dataset :  (9994, 13)

# %% [markdown]
# ##### Lets check whether dataset have null value or not

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# ##### Lets checks values count in each columns

# %%
data.count()
# Out:
# Ship Mode       9994
# Segment         9994
# Country         9994
# City            9994
# State           9994
# Postal Code     9994
# Region          9994
# Category        9994
# Sub-Category    9994
# Sales           9994
# Quantity        9994
# Discount        9994
# Profit          9994
# dtype: int64

# %% [markdown]
# ##### Lets check information datasets

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# ##### Exploering Data By using @interact Function
# ##### Lets check the summary statistics for each

# %%
### Exploering Data By using @interact Function

# Lets check the summary statistics for each   
@interact
def first_column(column1 = list(data.columns.value_counts().index)):
    print(column1)
    @interact
    def column_value(column_value = list(data[column1].value_counts().index)):
        print(column_value)
        y = data[data[column1] == column_value]
        print(y)
        @interact
        def second_column(column2 = list(data.columns.value_counts().index)):
            print(column2)
            @interact
            def numeric_analysis(aggregation = ["max()","min()","avg()","sum()"]):
                if aggregation == "max()":
                    print(f"{aggregation}   of  {column2} in {column1} is",y[column2].max())
                    a = y[column2].max()
                elif aggregation == "min()":
                    print(f"{aggregation}   of  {column2} in {column1} is",y[column2].min())
                    a = y[column2].min()
                elif aggregation == "avg":
                    print(f"{aggregation}   of  {column2} in {column1} is",y[column2].avg())
                    a1 = y[column2].avg()
                else:
                    print(f"{aggregation}   of  {column2} in {column1} is",y[column2].sum())
                    a1 = y[column2].sum()
                @interact
                def area_to_focus(column3 = list(data.columns.value_counts().index)):
                    area_to_focus = y[column2] == a 
                    print( area_to_focus )
                    print( y[column3]   == area_to_focus )
# Out:
# interactive(children=(Dropdown(description='column1', options=('Ship Mode', 'Segment', 'Country', 'City', 'Sta…

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ##### CONVERITNG THE NUMERICAL COLUMNS TO HISTOGRAM

# %%
data.hist(bins=50, figsize=(11,8))
# Out:
# array([[<AxesSubplot:title={'center':'Postal Code'}>,
#         <AxesSubplot:title={'center':'Sales'}>],
#        [<AxesSubplot:title={'center':'Quantity'}>,
#         <AxesSubplot:title={'center':'Discount'}>],
#        [<AxesSubplot:title={'center':'Profit'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data_f ={
    'Discount': data['Discount'],
    'Sales': data['Sales'],
    'Profit': data['Profit']
    
}

dataFrame = pd.DataFrame(datos_f, columns=['Discount','Sales','Profit'])

print(dataFrame)

corr = dataFrame.corr()
ax1 = sns.heatmap(corr, cmap="Blues", annot=True)
plt.show()
# Out:
#       Discount     Sales    Profit
# 0         0.00  261.9600   41.9136
# 1         0.00  731.9400  219.5820
# 2         0.00   14.6200    6.8714
# 3         0.45  957.5775 -383.0310
# 4         0.20   22.3680    2.5164
# ...        ...       ...       ...
# 9989      0.20   25.2480    4.1028
# 9990      0.00   91.9600   15.6332
# 9991      0.20  258.5760   19.3932
# 9992      0.00   29.6000   13.3200
# 9993      0.00  243.1600   72.9480
#
# [9994 rows x 3 columns]

# %% [markdown]
# #### SEGMENTWISE PROFIT IN EACH CATEGORY

# %%
sns.barplot(data=data, x='Segment', y='Profit', hue='Category')
#In all three segments Technology is making the highest profit
# Out:
# <AxesSubplot:xlabel='Segment', ylabel='Profit'>

# %%
data_F = pd.read_csv("SampleSuperstore.csv",  header=0, index_col=["State","Sales"],usecols= ["State","Sales","Profit"])


state_data = data_F[:20].copy()
state_data
# Out:
#                             Profit
# State          Sales
# Kentucky       261.9600    41.9136
#                731.9400   219.5820
# California     14.6200      6.8714
# Florida        957.5775  -383.0310
#                22.3680      2.5164
# California     48.8600     14.1694
#                7.2800       1.9656
#                907.1520    90.7152
#                18.5040      5.7825
#                114.9000    34.4700
#                1706.1840   85.3092
#                911.4240    68.3568
# North Carolina 15.5520      5.4432
# Washington     407.9760   132.5922
# Texas          68.8100   -123.8580
#                2.5440      -3.8160
# Wisconsin      665.8800    13.3176
# Utah           55.5000      9.9900
# California     8.5600       2.4824
#                213.4800    16.0110

# %%
state_data.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='State,Sales'>

# %%
x = data['Category']
y= data['Sales']

plt.bar(x, y)
 
# setting x-label as pen sold
plt.xlabel("pen sold")
 
# setting y_label as price
plt.ylabel("price")  
plt.title("Sales /Category")
plt.show()

# %%
x = data['Ship Mode']
y= data['Sales']

plt.bar(x, y)
 
# setting x-label as pen sold
plt.xlabel("pen sold")
 
# setting y_label as price
plt.ylabel("price")  
plt.title(" Sales / Ship Mode")
plt.show()

# %% [markdown]
# #### REGIONWISE SALES

# %%
sns.barplot(data=data, x='Sales', y='Region', hue='Country')
#South region is having highest almost fairly similar sales to that of east region
#Second highest region of sales being West
#Third Highest being Central in Sales
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Region'>

# %% [markdown]
# #### REGINWISE PORFIT

# %%
sns.barplot(data=data, x='Profit', y='Region', hue='Country')
#Highest profit is in West and East region
#Second Highest profit is in South region
#Third highest is in Central region
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Region'>

# %% [markdown]
# ANALYSIS by REGRESSION PLOT TO CHECK SALES AND PROFIT ARE CORRELATED

# %%
sns.regplot(x="Sales", y="Profit", data = data) 
#Sales and Profit are positively correlated
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Profit'>

# %% [markdown]
# ANALYSIS by USING REGRESSION PLOT TO CHECK SALES AND QUANTITY ARE CORRELATED

# %%
sns.regplot(x="Sales", y="Quantity", data = data) 
# Sales and Quantity are positively correlated
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Quantity'>

# %% [markdown]
# ANALYSIS by USING REGRESSION PLOT TO CHECK PROFIT AND QUANTITY ARE CORRELATED

# %%
sns.regplot(x="Profit", y="Quantity", data = data) #Profit and Quantity are positively correlated
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Quantity'>

# %% [markdown]
# #### ANALYSIS USING BOX PLOT TO CHECK WHETHER SHIP MODE AFFECTS THE SALES

# %%
data.boxplot(column="Sales",by="Ship Mode",figsize=(20,9))
#The box plot shows all the boxes lies in the same line without any change in position which shows there is no effect of shipmode on sales
# Out:
# <AxesSubplot:title={'center':'Sales'}, xlabel='Ship Mode'>

# %%
sns.set(style="whitegrid")
plt.figure(2, figsize=(20,15))
sns.barplot(x='Sub-Category',y='Profit', data=data, palette='Spectral')
plt.suptitle('Pie Consumption Patterns in the United States', fontsize=16)
plt.show()

# %% [markdown]
# ##### Lets Explore data by sets graphs

# %%
figsize=(15,10)
sns.pairplot(data,hue='Sub-Category')
plt.show()

# %% [markdown]
# ### Thank You
